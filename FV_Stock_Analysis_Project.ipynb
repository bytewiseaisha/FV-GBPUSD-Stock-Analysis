# %% [markdown]
# # 002

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
dataset= pd.read_csv("C:/Users/AISHA/Desktop/Datasets/GBPUSD=X_dataset.csv")

# %%
dataset
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2021-07-29  1.390821  1.398210  1.389989  1.390685   1.390685       0
# 1    2021-07-30  1.396433  1.398406  1.389719  1.396433   1.396433       0
# 2    2021-08-02  1.389661  1.393340  1.388503  1.389622   1.389622       0
# 3    2021-08-03  1.389101  1.394000  1.388600  1.389275   1.389275       0
# 4    2021-08-04  1.391595  1.395693  1.390144  1.391788   1.391788       0
# ..          ...       ...       ...       ...       ...        ...     ...
# 257  2022-07-25  1.198423  1.208313  1.196215  1.198696   1.198696       0
# 258  2022-07-26  1.205764  1.209219  1.196544  1.205516   1.205516       0
# 259  2022-07-27  1.203818  1.208664  1.202227  1.203688   1.203688       0
# 260  2022-07-28  1.216663  1.219051  1.210449  1.216308   1.216308       0
# 261  2022-07-29  1.217849  1.224155  1.213828  1.216737   1.216737       0
#
# [262 rows x 7 columns]

# %% [markdown]
# SCATTER PLOTS

# %%
# Plot using a scatter plot matrix or pairplot

sns.pairplot(dataset)
plt.show()

# %%
# Using several scatter plots to visualise for better view

columns = dataset.columns

for i in range(len(columns)):
    for j in range(i+1, len(columns)):
        # Create a new figure for each scatter plot
        plt.figure()
        plt.scatter(dataset[columns[i]], dataset[columns[j]])
        plt.xlabel(columns[i])
        plt.ylabel(columns[j])
        plt.title(f'{columns[i]} vs {columns[j]}')

        
        plt.close() # remove this line to see figures

        
plt.show()

# %%
# From the scatter plots above, there are outliers

# %% [markdown]
# LINEAR MODEL FOR TRADE OPEN AND TRADE CLOSE

# %%
# Specifying variables

x_1 = dataset[["Open"]]
y_1 = dataset[["Close"]]

# %%
# Train-test split

x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x_1,y_1, test_size=0.2, random_state=42)

# %%
# Creating and training model

model_1 =  LinearRegression()
model_1.fit(x_train_1, y_train_1)
# Out:
# LinearRegression()

# %%
# Making predictions on test data

y_pred_1 = model_1.predict(x_test_1)
y_pred_1
# Out:
# array([[1.18999262],
#        [1.25870303],
#        [1.25844902],
#        [1.31679892],
#        [1.38008007],
#        [1.35336974],
#        [1.31368577],
#        [1.21666294],
#        [1.38370825],
#        [1.35305872],
#        [1.37537783],
#        [1.25421881],
#        [1.34697142],
#        [1.22043513],
#        [1.28291024],
#        [1.19507087],
#        [1.34243219],
#        [1.3927857 ],
#        [1.24904955],
#        [1.3686515 ],
#        [1.35340674],
#        [1.36155114],
#        [1.3727857 ],
#        [1.25677294],
#        [1.34989857],
#        [1.35446979],
#        [1.34110013],
#        [1.36594136],
#        [1.32793847],
#        [1.37444579],
#        [1.3766599 ],
#        [1.27372578],
#        [1.21814502],
#        [1.34340624],
#        [1.38412927],
#        [1.31221969],
#        [1.35638089],
#        [1.22675344],
#        [1.23271174],
#        [1.3868554 ],
#        [1.18826753],
#        [1.3426302 ],
#        [1.35909002],
# ...

# %%
# Evaluating model

mse_1 = mean_squared_error (y_test_1, y_pred_1)
print (f" The mean squared error of the linear model for values of trade open and trade close is:  {mse_1}")
# Out:
#  The mean squared error of the linear model for values of trade open and trade close is:  5.1288217288498895e-08

# %%
# Slope
m_1 = model_1.coef_
print (f" The slope of the linear model for values of trade open and trade close is: {m_1}")
# Out:
#  The slope of the linear model for values of trade open and trade close is: [[1.00004972]]

# %%
# Intercept
c_1 = model_1.intercept_
print (f" The intercept of the linear model for values of trade open and trade close is: {c_1}")
# Out:
#  The intercept of the linear model for values of trade open and trade close is: [-6.05457025e-05]

# %%
# r_squared
r_squared_1 = r2_score(y_test_1, y_pred_1)
print (f" The r-squared value of the linear model for values of trade open and trade close is: {r_squared_1}")
# Out:
#  The r-squared value of the linear model for values of trade open and trade close is: 0.9999866363237433

# %%
# Correlation
correlation_matrix_1 = dataset[["Open", "Close"]].corr()
correlation_matrix_1
# Out:
#            Open     Close
# Open   1.000000  0.999994
# Close  0.999994  1.000000

# %% [markdown]
# LINEAR MODEL FOR STOCK HIGH AND STOCK LOW

# %%
# Create model
model_2 = LinearRegression()

# %%
# Declare variables
x_2 = dataset[["High"]]
y_2 = dataset[["Low"]]

# %%
# Train-test split
x_train_2, x_test_2, y_train_2, y_test_2 = train_test_split(x_2, y_2, test_size=0.25, random_state=40)

# %%
model_2.fit(x_train_2, y_train_2)
# Out:
# LinearRegression()

# %%
y_pred_2 = model_2.predict(x_test_2)

# %%
y_pred_2
# Out:
# array([[1.29722874],
#        [1.32621225],
#        [1.36545405],
#        [1.3870767 ],
#        [1.35699019],
#        [1.37423687],
#        [1.33709612],
#        [1.36533778],
#        [1.2235049 ],
#        [1.21741372],
#        [1.35088461],
#        [1.32668041],
#        [1.37906454],
#        [1.36727934],
#        [1.29845932],
#        [1.19407072],
#        [1.23871947],
#        [1.31245462],
#        [1.29587777],
#        [1.22658856],
#        [1.25601759],
#        [1.21834695],
#        [1.2481752 ],
#        [1.22031218],
#        [1.36012118],
#        [1.37176644],
#        [1.37182509],
#        [1.34679261],
#        [1.24078039],
#        [1.20036254],
#        [1.34936593],
#        [1.212691  ],
#        [1.32852628],
#        [1.22602163],
#        [1.30539421],
#        [1.30135263],
#        [1.25540745],
#        [1.35379747],
#        [1.38009345],
#        [1.18606576],
#        [1.35457944],
#        [1.30553723],
#        [1.35628127],
# ...

# %%
# Evaluation
mse_2 = mean_squared_error (y_test_2, y_pred_2)
print (f" The mean squared error of the linear model for values of stock high and stock low is: {mse_2}")
# Out:
#  The mean squared error of the linear model for values of stock high and stock low is: 8.603923192740653e-06

# %%
# Intercept
c_2 = model_2.intercept_
print (f" The intercept of the linear model for values of stock high and stock low is: {c_2}")
# Out:
#  The intercept of the linear model for values of stock high and stock low is: [-0.04723114]

# %%
# Slope
m_2 = model_2.coef_
print (f" The slope of the linear model for values of stock high and stock low is: {m_2}")
# Out:
#  The slope of the linear model for values of stock high and stock low is: [[1.02891524]]

# %%
# rsquared
r_squared_2 = r2_score(y_test_2, y_pred_2)
print (f" The rsquared value of the linear model for values of stock high and stock low is: {r_squared_2}")
# Out:
#  The rsquared value of the linear model for values of stock high and stock low is: 0.9978255186628753

# %%
# Correlation
correlation_matrix_2 = dataset[["High", "Low"]].corr()
correlation_matrix_2
# Out:
#           High       Low
# High  1.000000  0.997965
# Low   0.997965  1.000000

# %% [markdown]
# VISUALIZING RESULTS

# %%
# Trade open and Trade close 
# Red is regression line
plt.scatter(x_train_1, y_train_1)
plt.scatter(x_test_1, y_pred_1, color="red")

# %%
# Stock high and stock low
# Red is regression line
plt.scatter(x_train_2, y_train_2)
plt.scatter(x_test_2, y_pred_2, color="red")
